# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.functions import col, isnull, when
from pyspark.sql.types import TimestampType
from notebookutils import notebook
# from datetime import date, timedelta
# Out:
# StatementMeta(, 7d2ed5ce-4684-403a-a765-ee11a4e9a022, 3, Finished, Available, Finished)

# %%
# Remove this before running Data Factory Pipeline
# start_date = date.today() - timedelta(7)
# Out:
# StatementMeta(, 3a272781-34e2-4310-ae72-73728f8e0766, 5, Finished, Available, Finished)

# %%
#Load the Json data into a spark Dataframe 
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 3a272781-34e2-4310-ae72-73728f8e0766, 6, Finished, Available, Finished)

# %%
print(df.head())
# Out:
# StatementMeta(, 3a272781-34e2-4310-ae72-73728f8e0766, 10, Finished, Available, Finished)
# Row(id='ak0259qzz9gy', longitude=-151.9399, latitude=60.2156, elevation=71.0, title='M 1.5 - 23 km NW of Ninilchik, Alaska', place_description='23 km NW of Ninilchik, Alaska', sig=35, mag=1.5, magType='ml', time=datetime.datetime(2025, 7, 31, 23, 59, 33, 947000), updated=datetime.datetime(2025, 8, 1, 0, 1, 35, 484000))

# %%
#Reshape earthquake data
df = (
    df
    .select( 
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
    )
)
# Out:
# StatementMeta(, 3a272781-34e2-4310-ae72-73728f8e0766, 8, Finished, Available, Finished)

# %%
# Convert time and update to timestamp
df = (
    df.withColumn('time', (col('time') / 1000).cast(TimestampType()))
    .withColumn('updated', (col('updated') / 1000).cast(TimestampType()))
)
# Out:
# StatementMeta(, 3a272781-34e2-4310-ae72-73728f8e0766, 9, Finished, Available, Finished)

# %%
# Append to the silver table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 3a272781-34e2-4310-ae72-73728f8e0766, 11, Finished, Available, Finished)

# %%
notebook.exit({
    "start_date": start_date
})
# Out:
# StatementMeta(, 7d2ed5ce-4684-403a-a765-ee11a4e9a022, 4, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 notebook.exit({
# ----> 2     "start_date": start_date
#       3 })
#
# NameError: name 'start_date' is not defined
