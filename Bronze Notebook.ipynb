# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import requests
import json
from notebookutils import notebook
# from datetime import date, timedelta
# Out:
# StatementMeta(, 1e4903ce-be9e-4994-b93b-c05e0bc682f4, 3, Finished, Available, Finished)

# %%
# Remove this before running Data Factory Pipeline
# start_date = date.today() - timedelta(7)
# end_date = date.today() - timedelta(1)
# Out:
# StatementMeta(, f0034f6e-1d91-404e-a350-86afcece08c8, 5, Finished, Available, Finished)

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"
# Out:
# StatementMeta(, f0034f6e-1d91-404e-a350-86afcece08c8, 6, Finished, Available, Finished)

# %%
url
# Out:
# StatementMeta(, f0034f6e-1d91-404e-a350-86afcece08c8, 7, Finished, Available, Finished)
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-07-26&endtime=2025-08-01'

# %%
try:
    # Make the GET request to fetch data
    response = requests.get(url)
    # Check if the request was successful
    response.raise_for_status() # Raise HTTPError for bad response (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified data range. ")
    else:
        file_path = f'/lakehouse/default/Files/{start_date}_earthquake_data.json'
        # Save the JSON
        with open(file_path, 'w') as file:
            json.dump(data, file, indent=4)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as err:
    print(f"Error fetching data from API: {err}")
# Out:
# StatementMeta(, f0034f6e-1d91-404e-a350-86afcece08c8, 9, Finished, Available, Finished)
# Data successfully saved to /lakehouse/default/Files/2025-07-26_earthquake_data.json

# %%
notebook.exit({
    "start_date": start_date,
    "end_date": end_date
})
# Out:
# StatementMeta(, 1e4903ce-be9e-4994-b93b-c05e0bc682f4, 4, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 notebook.exit({
# ----> 2     "start_date": start_date,
#       3     "end_date": end_date
#       4 })
#
# NameError: name 'start_date' is not defined
